# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# added md cell for test

# %%
rng = np.random.RandomState(2) # small change in code but big change in output
data = rng.normal(0, 1, 1000)
plt.plot(data+1)
plt.show()
